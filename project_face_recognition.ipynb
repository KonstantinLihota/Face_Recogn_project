# %% [markdown]
# <a href="https://colab.research.google.com/github/KonstantinLihota/Face_Recogn_project/blob/main/project_face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Face Recognition

# %% [markdown]
# ### !!This is a basic notebook, completing which you can get (preliminarly) 5/10 ponints. Other tasks which will get you more ponts are describes in a Slack channel.

# %% [markdown]
# ![Screenshot 2021-11-03 at 20.52.29.png](data:image/png;base64,...)

# %% [markdown]
# In this project you'll dive into face recognition framework and train neural network for face recognition task, play with losses and metrics.
#
# We will train neural network on [CelebA dataset](https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html).

# %% [markdown]
# As you see on the site, images of celebA dataset look like this:
#
#
# ![Screenshot 2021-11-03 at 19.15.27.png](data:image/png;base64,...)

# %% [markdown]
# But we won't train a neural network for face recognition on those images. We'll need to preprocess them first. Let's see why we need it and how we need to preprocess them.

# %% [markdown]
# Let's look at how face recognition systems work:

# %% [markdown]
# ## Face recognition model training and inference setup
#
# This section describes how face recognition models are trained, what data alignment is and how the inference of face recognition model looks like. If you are familiar with this, you can skip this section.

# %% [markdown]
# ### Model training

# %% [markdown]
# To train face recognition model on any facial dataset images must be aligned first. This step is very important to achieve a good quality of face recognition.
#
# What is alignment: it consists of three steps:
# 1. Given image, identify facial landmarks on the image (coordinates of eyes, nose and mouth points). Separate neural network can be used there which was trained to identify landmarks on facial images. You can refer to [PyTorch Landmarks tutorial](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html) to see how this works.
# 2. Rotate all the images in the dataset so that eyes of the person on every image lie on a certain pre-defined horizontal line.
# 3. Scale all the images in the dataset so that the size of the faces are approximately identical.
#
# Here's an example of what we would get after alignment of all the images of Aaron Peirsol from our dataset:

# %% [markdown]
# ![Screenshot 2021-11-03 at 00.30.10.png](data:image/png;base64,...)

# %% [markdown]
# You see that eyes of all the faces lie on one horizontal line and all the faces have almost the same size. If we align all the images in the dataset, we can then train a neural network on aligned images.

# %% [markdown]
# **Why we need the alignment procedure**: the alignment of all faces in dataset makes the task of facial recognition easier for the model. If all the faces that model sees are of the same size and have their landmarks (eyes, nose, etc) on almost the same parts of the images, it is easier for the model to learn to identify a person on the image. The model diesn't need to "search" for the face and eyes positions on the image befire performing a recognition.
#
# If you are interested, you can also train a model on non-aligned images, but you'll see that it would perform badly. It is possible though to train a model for face recognition without pre-alignment of all the faces, but this would require a huge amount of data — more that almost any company has. The only company that has openly presented its face recognition system that does not require special alignment is Facebook — their neural network was trained on a really huge amount of data using a special trick to avoid alignment. You can read more details [here](https://research.fb.com/publications/deepface-closing-the-gap-to-human-level-performance-in-face-verification/)

# %% [markdown]
# ### Model inference

# %% [markdown]
# So let's see how the model trained on aligned faces can be used in real world:
#
# Let's assume you owe a company and you want to build a face recognition system for your working office. You decided to hang some cameras around the office and want them to be able to recognize faces of all your employees when they are sitting / walking around the office (we let you decide by yourself why you would need such a system in your office)
#
#
# A system for face recognition typically conststs of 3 stages:
# - face detection
# - face alignment
# - face recognition
#
# Let's discuss them in detail:

# %% [markdown]
# **Face detection**
#
# When the camera is hanged on the wall it records a video and splits the video into single images, like this:

# %% [markdown]
# ![photo_2021-11-02 23.53.59.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# To be able to recognize all the faces on the photo you need first to detect all the faces that are present on the photo, like this:

# %% [markdown]
# ![Screenshot 2021-11-03 at 00.09.30.png](data:image/png;base64,...)

# %% [markdown]
# That is the first part — detection. You could use any neural network that can detect humans for this.

# %% [markdown]
# **Face alignment**
#
# The second stage is to align all the faces found. The alignment procedure here should be the same as used to align training images.
#
# So we'll get an image of a guy on a photo aligned like this:

# %% [markdown]
# ![photo_2021-11-03 00.16.17.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Face recognition**
#
# On the third stage we use the neural network that we trained to recognize a face.

# %% [markdown]
# So that's how the face recognition models pipeline work. You can also read about it more on [this link](https://www.nytimes.com/wirecutter/blog/how-facial-recognition-works/) (and using internet search)

# %% [markdown]
# ## Neural network model architecture

# %% [markdown]
# Let's discuss how model for face recognition should look like.

# %% [markdown]
# The easiest and, actually, the most used way to build a neural network for face recognition is to build it as a **simple classifier**.
#
# Assume we have a dataset with photos of N different people. Then we can build a neural network to classify all the images from the dataset into N classes. Each class refers to one unique person in the dataset.

# %% [markdown]
# **How do we recognize new people by this network then?** We actually want the network for face recognition to be able to recognize not only the people which are in training set, but almost every person in the world.
#
# That is how: after training the model, we'll drop it's last classification layer. After that when we'll pass an image of the person through network, we'll get the output of the pre-last layer — it's **the embedding of the image**. Having embeddings of two different images we can compare them using **cosine distance**. The less the distance is — the higher the probability that those two photos belong to one person is.
#
# Using that technique we can get embeddings of every image — even of unseen people, compare them, and reveal images belonging to same people.

# %% [markdown]
# ![Screenshot 2021-11-03 at 01.27.07.png](data:image/png;base64,...)

# %% [markdown]
# ## Task 1 (30% points): build a neural network for faces classification as discribed above.

# %% [markdown]
# ### Dataset

# %% [markdown]
# We will train out face recognition network on part of the [CelebA dataset](https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html). But we'll use a version of it that has all the images in it aligned and cropped. You can download the dataset using this link: https://disk.yandex.ru/d/S8f03spLIA1wrw

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')
#from reco_utils.recommender.sar.sar_singlenode import SARSingleNode
from google.colab import drive
drive.mount('/content/gdrive')


#DATA_DIR = '/content/gdrive/MyDrive/data/faces_dataset'
# Out:
# Mounted at /content/gdrive

# %%
# this link won't work for you, if you want to generate working link 
# visit https://askubuntu.com/questions/1188381/how-to-get-link-of-file-to-download-with-wget
# or download the data and place it to folder manually
#! wget "https://s404man.storage.yandex.net/rdisk/e0e5e83a8ed50a2dfedfc6bbe1081de4949c81c87d5410c45c2cedb578851f6a/618475fd/aZ8Akc9CqtcaAMvg9MkExUmNfU9U_vPugtmtwAC7LCh7Ob4GqD-JrqJl2rsy_hxC-1lho6HNKGxRJzyaqhvCBg==?uid=316082386&filename=celebA_train_500.zip&disposition=attachment&hash=&limit=0&content_type=application%2Fzip&owner_uid=316082386&fsize=170342993&hid=8e5296bb80b8febc2b500d8fd890bbcf&media_type=compressed&tknv=v2&etag=1b0518cba143d479efa9e581d57ead35&rtoken=Ny3K3Z2QBMXq&force_default=yes&ycrid=na-9388316a3a9a2e64a8e248d7729518fe-downloader8f&ts=5cfff715bb940&s=ec587c110763937cfa598cc4f80ae49bcf87d3f82f3ad4c67cc053b2961d3a3b&pb=U2FsdGVkX1_M1VrRqOVGHQ-RDMSpA0_18Qqau6zdD_w8F5__FE9yGJWvrQlF_6i82qf1CSgs4iy4r74kLxZEQ9_ykd_KwAh7b5R393KQquE" -O celebA.zip
! unzip /content/gdrive/MyDrive/data/celebA_train_1k.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: celebA_train_1k/celebA_imgs/049159.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049159.jpg
#   inflating: celebA_train_1k/celebA_imgs/105435.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105435.jpg
#   inflating: celebA_train_1k/celebA_imgs/068197.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._068197.jpg
#   inflating: celebA_train_1k/celebA_imgs/092985.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._092985.jpg
#   inflating: celebA_train_1k/celebA_imgs/057367.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._057367.jpg
#   inflating: celebA_train_1k/celebA_imgs/097625.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._097625.jpg
#   inflating: celebA_train_1k/celebA_imgs/157415.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._157415.jpg
#   inflating: celebA_train_1k/celebA_imgs/131790.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._131790.jpg
#   inflating: celebA_train_1k/celebA_imgs/088705.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._088705.jpg
#   inflating: celebA_train_1k/celebA_imgs/003736.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._003736.jpg
#   inflating: celebA_train_1k/celebA_imgs/107544.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._107544.jpg
#   inflating: celebA_train_1k/celebA_imgs/053667.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._053667.jpg
#   inflating: celebA_train_1k/celebA_imgs/158040.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._158040.jpg
#   inflating: celebA_train_1k/celebA_imgs/088063.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._088063.jpg
#   inflating: celebA_train_1k/celebA_imgs/147160.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._147160.jpg
#   inflating: celebA_train_1k/celebA_imgs/043474.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._043474.jpg
#   inflating: celebA_train_1k/celebA_imgs/098270.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._098270.jpg
#   inflating: celebA_train_1k/celebA_imgs/116449.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._116449.jpg
#   inflating: celebA_train_1k/celebA_imgs/019008.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._019008.jpg
#   inflating: celebA_train_1k/celebA_imgs/105353.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105353.jpg
#   inflating: celebA_train_1k/celebA_imgs/000559.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000559.jpg
#   inflating: celebA_train_1k/celebA_imgs/007236.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._007236.jpg
#   inflating: celebA_train_1k/celebA_imgs/084881.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._084881.jpg
#   inflating: celebA_train_1k/celebA_imgs/076424.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._076424.jpg
#   inflating: celebA_train_1k/celebA_imgs/060246.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._060246.jpg
#   inflating: celebA_train_1k/celebA_imgs/067529.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067529.jpg
#   inflating: celebA_train_1k/celebA_imgs/036000.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._036000.jpg
#   inflating: celebA_train_1k/celebA_imgs/138987.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._138987.jpg
#   inflating: celebA_train_1k/celebA_imgs/022075.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._022075.jpg
#   inflating: celebA_train_1k/celebA_imgs/136772.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._136772.jpg
#   inflating: celebA_train_1k/celebA_imgs/032266.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._032266.jpg
#   inflating: celebA_train_1k/celebA_imgs/053854.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._053854.jpg
#   inflating: celebA_train_1k/celebA_imgs/072642.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._072642.jpg
#   inflating: celebA_train_1k/celebA_imgs/045950.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._045950.jpg
#   inflating: celebA_train_1k/celebA_imgs/149818.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._149818.jpg
#   inflating: celebA_train_1k/celebA_imgs/075893.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._075893.jpg
#   inflating: celebA_train_1k/celebA_imgs/064746.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._064746.jpg
#   inflating: celebA_train_1k/celebA_imgs/132272.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._132272.jpg
#   inflating: celebA_train_1k/celebA_imgs/008850.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._008850.jpg
#   inflating: celebA_train_1k/celebA_imgs/104918.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._104918.jpg
#   inflating: celebA_train_1k/celebA_imgs/036772.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._036772.jpg
#   inflating: celebA_train_1k/celebA_imgs/132266.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._132266.jpg
#   inflating: celebA_train_1k/celebA_imgs/026561.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._026561.jpg
#   inflating: celebA_train_1k/celebA_imgs/057398.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._057398.jpg
#   inflating: celebA_train_1k/celebA_imgs/124404.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._124404.jpg
#   inflating: celebA_train_1k/celebA_imgs/071439.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._071439.jpg
#   inflating: celebA_train_1k/celebA_imgs/133178.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._133178.jpg
#   inflating: celebA_train_1k/celebA_imgs/115801.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._115801.jpg
#   inflating: celebA_train_1k/celebA_imgs/069276.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._069276.jpg
#   inflating: celebA_train_1k/celebA_imgs/088922.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._088922.jpg
#   inflating: celebA_train_1k/celebA_imgs/120662.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._120662.jpg
#   inflating: celebA_train_1k/celebA_imgs/139333.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._139333.jpg
#   inflating: celebA_train_1k/celebA_imgs/003911.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._003911.jpg
#   inflating: celebA_train_1k/celebA_imgs/064752.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._064752.jpg
#   inflating: celebA_train_1k/celebA_imgs/151925.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._151925.jpg
#   inflating: celebA_train_1k/celebA_imgs/160520.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160520.jpg
#   inflating: celebA_train_1k/celebA_imgs/136766.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._136766.jpg
#   inflating: celebA_train_1k/celebA_imgs/015815.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._015815.jpg
#   inflating: celebA_train_1k/celebA_imgs/124362.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._124362.jpg
#   inflating: celebA_train_1k/celebA_imgs/112808.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._112808.jpg
#   inflating: celebA_train_1k/celebA_imgs/049818.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049818.jpg
#   inflating: celebA_train_1k/celebA_imgs/026207.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._026207.jpg
#   inflating: celebA_train_1k/celebA_imgs/067515.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067515.jpg
#   inflating: celebA_train_1k/celebA_imgs/093494.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._093494.jpg
#   inflating: celebA_train_1k/celebA_imgs/067273.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067273.jpg
#   inflating: celebA_train_1k/celebA_imgs/142971.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._142971.jpg
#   inflating: celebA_train_1k/celebA_imgs/051919.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._051919.jpg
#   inflating: celebA_train_1k/celebA_imgs/077060.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._077060.jpg
#   inflating: celebA_train_1k/celebA_imgs/058083.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._058083.jpg
#   inflating: celebA_train_1k/celebA_imgs/103093.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._103093.jpg
#   inflating: celebA_train_1k/celebA_imgs/113280.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113280.jpg
#   inflating: celebA_train_1k/celebA_imgs/147809.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._147809.jpg
#   inflating: celebA_train_1k/celebA_imgs/161164.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._161164.jpg
#   inflating: celebA_train_1k/celebA_imgs/014289.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._014289.jpg
#   inflating: celebA_train_1k/celebA_imgs/128202.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._128202.jpg
#   inflating: celebA_train_1k/celebA_imgs/034159.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._034159.jpg
#   inflating: celebA_train_1k/celebA_imgs/137322.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._137322.jpg
#   inflating: celebA_train_1k/celebA_imgs/033636.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._033636.jpg
#   inflating: celebA_train_1k/celebA_imgs/086933.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._086933.jpg
#   inflating: celebA_train_1k/celebA_imgs/045978.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._045978.jpg
#   inflating: celebA_train_1k/celebA_imgs/090189.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._090189.jpg
#   inflating: celebA_train_1k/celebA_imgs/093480.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._093480.jpg
#   inflating: celebA_train_1k/celebA_imgs/068154.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._068154.jpg
#   inflating: celebA_train_1k/celebA_imgs/021232.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._021232.jpg
#   inflating: celebA_train_1k/celebA_imgs/125726.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._125726.jpg
#   inflating: celebA_train_1k/celebA_imgs/048284.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._048284.jpg
#   inflating: celebA_train_1k/celebA_imgs/102399.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._102399.jpg
#   inflating: celebA_train_1k/celebA_imgs/061616.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._061616.jpg
#   inflating: celebA_train_1k/celebA_imgs/078421.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._078421.jpg
#   inflating: celebA_train_1k/celebA_imgs/049824.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049824.jpg
#   inflating: celebA_train_1k/celebA_imgs/029108.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._029108.jpg
#   inflating: celebA_train_1k/celebA_imgs/036028.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._036028.jpg
#   inflating: celebA_train_1k/celebA_imgs/103939.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._103939.jpg
#   inflating: celebA_train_1k/celebA_imgs/004924.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._004924.jpg
#   inflating: celebA_train_1k/celebA_imgs/073574.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._073574.jpg
#   inflating: celebA_train_1k/celebA_imgs/035521.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._035521.jpg
#   inflating: celebA_train_1k/celebA_imgs/107587.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._107587.jpg
#   inflating: celebA_train_1k/celebA_imgs/159612.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._159612.jpg
#   inflating: celebA_train_1k/celebA_imgs/107008.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._107008.jpg
#   inflating: celebA_train_1k/celebA_imgs/160093.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160093.jpg
#   inflating: celebA_train_1k/celebA_imgs/119236.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._119236.jpg
#   inflating: celebA_train_1k/celebA_imgs/150150.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._150150.jpg
#   inflating: celebA_train_1k/celebA_imgs/071834.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._071834.jpg
#   inflating: celebA_train_1k/celebA_imgs/124809.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._124809.jpg
#   inflating: celebA_train_1k/celebA_imgs/016677.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016677.jpg
#   inflating: celebA_train_1k/celebA_imgs/112363.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._112363.jpg
#   inflating: celebA_train_1k/celebA_imgs/000015.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000015.jpg
#   inflating: celebA_train_1k/celebA_imgs/142554.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._142554.jpg
#   inflating: celebA_train_1k/celebA_imgs/028799.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._028799.jpg
#   inflating: celebA_train_1k/celebA_imgs/152021.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._152021.jpg
#   inflating: celebA_train_1k/celebA_imgs/114074.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._114074.jpg
#   inflating: celebA_train_1k/celebA_imgs/104267.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._104267.jpg
#   inflating: celebA_train_1k/celebA_imgs/078810.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._078810.jpg
#   inflating: celebA_train_1k/celebA_imgs/142232.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._142232.jpg
#   inflating: celebA_train_1k/celebA_imgs/000773.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000773.jpg
#   inflating: celebA_train_1k/celebA_imgs/030868.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._030868.jpg
#   inflating: celebA_train_1k/celebA_imgs/119550.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._119550.jpg
#   inflating: celebA_train_1k/celebA_imgs/116663.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._116663.jpg
#   inflating: celebA_train_1k/celebA_imgs/129493.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._129493.jpg
#   inflating: celebA_train_1k/celebA_imgs/044131.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._044131.jpg
#   inflating: celebA_train_1k/celebA_imgs/088249.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._088249.jpg
#   inflating: celebA_train_1k/celebA_imgs/159174.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._159174.jpg
#   inflating: celebA_train_1k/celebA_imgs/089143.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._089143.jpg
#   inflating: celebA_train_1k/celebA_imgs/160939.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160939.jpg
#   inflating: celebA_train_1k/celebA_imgs/073951.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._073951.jpg
#   inflating: celebA_train_1k/celebA_imgs/055028.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._055028.jpg
#   inflating: celebA_train_1k/celebA_imgs/021971.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._021971.jpg
#   inflating: celebA_train_1k/celebA_imgs/000767.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000767.jpg
#   inflating: celebA_train_1k/celebA_imgs/049401.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049401.jpg
#   inflating: celebA_train_1k/celebA_imgs/085779.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._085779.jpg
#   inflating: celebA_train_1k/celebA_imgs/123814.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._123814.jpg
#   inflating: celebA_train_1k/celebA_imgs/154444.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._154444.jpg
#   inflating: celebA_train_1k/celebA_imgs/069909.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._069909.jpg
#   inflating: celebA_train_1k/celebA_imgs/094674.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._094674.jpg
#   inflating: celebA_train_1k/celebA_imgs/006470.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._006470.jpg
#   inflating: celebA_train_1k/celebA_imgs/142540.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._142540.jpg
#   inflating: celebA_train_1k/celebA_imgs/000001.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000001.jpg
#   inflating: celebA_train_1k/celebA_imgs/113069.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113069.jpg
#   inflating: celebA_train_1k/celebA_imgs/056247.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._056247.jpg
#   inflating: celebA_train_1k/celebA_imgs/146726.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._146726.jpg
#   inflating: celebA_train_1k/celebA_imgs/086516.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._086516.jpg
#   inflating: celebA_train_1k/celebA_imgs/089625.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._089625.jpg
#   inflating: celebA_train_1k/celebA_imgs/087608.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._087608.jpg
#   inflating: celebA_train_1k/celebA_imgs/158518.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._158518.jpg
#   inflating: celebA_train_1k/celebA_imgs/023800.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._023800.jpg
#   inflating: celebA_train_1k/celebA_imgs/074780.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._074780.jpg
#   inflating: celebA_train_1k/celebA_imgs/054450.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._054450.jpg
#   inflating: celebA_train_1k/celebA_imgs/006458.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._006458.jpg
#   inflating: celebA_train_1k/celebA_imgs/057171.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._057171.jpg
#   inflating: celebA_train_1k/celebA_imgs/153465.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._153465.jpg
#   inflating: celebA_train_1k/celebA_imgs/071808.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._071808.jpg
#   inflating: celebA_train_1k/celebA_imgs/105623.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105623.jpg
#   inflating: celebA_train_1k/celebA_imgs/068381.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._068381.jpg
#   inflating: celebA_train_1k/celebA_imgs/113041.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113041.jpg
#   inflating: celebA_train_1k/celebA_imgs/000029.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000029.jpg
#   inflating: celebA_train_1k/celebA_imgs/151272.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._151272.jpg
#   inflating: celebA_train_1k/celebA_imgs/118114.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._118114.jpg
#   inflating: celebA_train_1k/celebA_imgs/110548.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._110548.jpg
#   inflating: celebA_train_1k/celebA_imgs/158530.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._158530.jpg
#   inflating: celebA_train_1k/celebA_imgs/100983.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._100983.jpg
#   inflating: celebA_train_1k/celebA_imgs/005151.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._005151.jpg
#   inflating: celebA_train_1k/celebA_imgs/101445.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._101445.jpg
#   inflating: celebA_train_1k/celebA_imgs/043662.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._043662.jpg
#   inflating: celebA_train_1k/celebA_imgs/062874.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._062874.jpg
#   inflating: celebA_train_1k/celebA_imgs/002158.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._002158.jpg
#   inflating: celebA_train_1k/celebA_imgs/091724.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._091724.jpg
#   inflating: celebA_train_1k/celebA_imgs/146068.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._146068.jpg
#   inflating: celebA_train_1k/celebA_imgs/056509.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._056509.jpg
#   inflating: celebA_train_1k/celebA_imgs/018100.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._018100.jpg
#   inflating: celebA_train_1k/celebA_imgs/021781.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._021781.jpg
#   inflating: celebA_train_1k/celebA_imgs/083320.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._083320.jpg
#   inflating: celebA_train_1k/celebA_imgs/000997.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000997.jpg
#   inflating: celebA_train_1k/celebA_imgs/113733.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113733.jpg
#   inflating: celebA_train_1k/celebA_imgs/092239.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._092239.jpg
#   inflating: celebA_train_1k/celebA_imgs/030840.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._030840.jpg
#   inflating: celebA_train_1k/celebA_imgs/125281.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._125281.jpg
#   inflating: celebA_train_1k/celebA_imgs/093127.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._093127.jpg
#   inflating: celebA_train_1k/celebA_imgs/123828.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._123828.jpg
#   inflating: celebA_train_1k/celebA_imgs/031586.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._031586.jpg
#   inflating: celebA_train_1k/celebA_imgs/000983.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000983.jpg
#   inflating: celebA_train_1k/celebA_imgs/097341.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._097341.jpg
#   inflating: celebA_train_1k/celebA_imgs/147362.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._147362.jpg
#   inflating: celebA_train_1k/celebA_imgs/005623.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._005623.jpg
#   inflating: celebA_train_1k/celebA_imgs/126788.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._126788.jpg
#   inflating: celebA_train_1k/celebA_imgs/087152.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._087152.jpg
#   inflating: celebA_train_1k/celebA_imgs/151500.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._151500.jpg
#   inflating: celebA_train_1k/celebA_imgs/035938.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._035938.jpg
#   inflating: celebA_train_1k/celebA_imgs/137685.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._137685.jpg
#   inflating: celebA_train_1k/celebA_imgs/089619.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._089619.jpg
#   inflating: celebA_train_1k/celebA_imgs/121781.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._121781.jpg
#   inflating: celebA_train_1k/celebA_imgs/058256.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._058256.jpg
#   inflating: celebA_train_1k/celebA_imgs/037849.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._037849.jpg
#   inflating: celebA_train_1k/celebA_imgs/105637.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105637.jpg
#   inflating: celebA_train_1k/celebA_imgs/143662.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._143662.jpg
#   inflating: celebA_train_1k/celebA_imgs/155000.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._155000.jpg
#   inflating: celebA_train_1k/celebA_imgs/104529.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._104529.jpg
#   inflating: celebA_train_1k/celebA_imgs/016887.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016887.jpg
#   inflating: celebA_train_1k/celebA_imgs/069060.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._069060.jpg
#   inflating: celebA_train_1k/celebA_imgs/162647.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._162647.jpg
#   inflating: celebA_train_1k/celebA_imgs/036564.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._036564.jpg
#   inflating: celebA_train_1k/celebA_imgs/146929.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._146929.jpg
#   inflating: celebA_train_1k/celebA_imgs/022511.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._022511.jpg
#   inflating: celebA_train_1k/celebA_imgs/073038.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._073038.jpg
#   inflating: celebA_train_1k/celebA_imgs/013914.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._013914.jpg
#   inflating: celebA_train_1k/celebA_imgs/140380.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._140380.jpg
#   inflating: celebA_train_1k/celebA_imgs/054487.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._054487.jpg
#   inflating: celebA_train_1k/celebA_imgs/111871.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._111871.jpg
#   inflating: celebA_train_1k/celebA_imgs/120474.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._120474.jpg
#   inflating: celebA_train_1k/celebA_imgs/052790.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._052790.jpg
#   inflating: celebA_train_1k/celebA_imgs/043845.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._043845.jpg
#   inflating: celebA_train_1k/celebA_imgs/156284.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._156284.jpg
#   inflating: celebA_train_1k/celebA_imgs/034415.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._034415.jpg
#   inflating: celebA_train_1k/celebA_imgs/146097.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._146097.jpg
#   inflating: celebA_train_1k/celebA_imgs/109958.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._109958.jpg
#   inflating: celebA_train_1k/celebA_imgs/099387.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._099387.jpg
#   inflating: celebA_train_1k/celebA_imgs/000968.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000968.jpg
#   inflating: celebA_train_1k/celebA_imgs/113900.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113900.jpg
#   inflating: celebA_train_1k/celebA_imgs/144858.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._144858.jpg
#   inflating: celebA_train_1k/celebA_imgs/040380.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._040380.jpg
#   inflating: celebA_train_1k/celebA_imgs/134373.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._134373.jpg
#   inflating: celebA_train_1k/celebA_imgs/065128.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._065128.jpg
#   inflating: celebA_train_1k/celebA_imgs/150839.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._150839.jpg
#   inflating: celebA_train_1k/celebA_imgs/136564.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._136564.jpg
#   inflating: celebA_train_1k/celebA_imgs/139657.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._139657.jpg
#   inflating: celebA_train_1k/celebA_imgs/032716.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._032716.jpg
#   inflating: celebA_train_1k/celebA_imgs/162653.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._162653.jpg
#   inflating: celebA_train_1k/celebA_imgs/078179.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._078179.jpg
#   inflating: celebA_train_1k/celebA_imgs/070525.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._070525.jpg
#   inflating: celebA_train_1k/celebA_imgs/132064.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._132064.jpg
#   inflating: celebA_train_1k/celebA_imgs/047389.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._047389.jpg
#   inflating: celebA_train_1k/celebA_imgs/125518.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._125518.jpg
#   inflating: celebA_train_1k/celebA_imgs/131545.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._131545.jpg
#   inflating: celebA_train_1k/celebA_imgs/126039.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._126039.jpg
#   inflating: celebA_train_1k/celebA_imgs/096936.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._096936.jpg
#   inflating: celebA_train_1k/celebA_imgs/159835.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._159835.jpg
#   inflating: celebA_train_1k/celebA_imgs/130883.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._130883.jpg
#   inflating: celebA_train_1k/celebA_imgs/002825.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._002825.jpg
#   inflating: celebA_train_1k/celebA_imgs/033420.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._033420.jpg
#   inflating: celebA_train_1k/celebA_imgs/017596.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._017596.jpg
#   inflating: celebA_train_1k/celebA_imgs/092588.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._092588.jpg
#   inflating: celebA_train_1k/celebA_imgs/021024.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._021024.jpg
#   inflating: celebA_train_1k/celebA_imgs/067071.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067071.jpg
#   inflating: celebA_train_1k/celebA_imgs/059821.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._059821.jpg
#   inflating: celebA_train_1k/celebA_imgs/077504.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._077504.jpg
#   inflating: celebA_train_1k/celebA_imgs/155969.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._155969.jpg
#   inflating: celebA_train_1k/celebA_imgs/000954.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000954.jpg
#   inflating: celebA_train_1k/celebA_imgs/094847.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._094847.jpg
#   inflating: celebA_train_1k/celebA_imgs/003285.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._003285.jpg
#   inflating: celebA_train_1k/celebA_imgs/023155.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._023155.jpg
#   inflating: celebA_train_1k/celebA_imgs/149398.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._149398.jpg
#   inflating: celebA_train_1k/celebA_imgs/063571.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._063571.jpg
#   inflating: celebA_train_1k/celebA_imgs/032058.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._032058.jpg
#   inflating: celebA_train_1k/celebA_imgs/128766.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._128766.jpg
#   inflating: celebA_train_1k/celebA_imgs/065114.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._065114.jpg
#   inflating: celebA_train_1k/celebA_imgs/116688.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._116688.jpg
#   inflating: celebA_train_1k/celebA_imgs/136558.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._136558.jpg
#   inflating: celebA_train_1k/celebA_imgs/158281.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._158281.jpg
#   inflating: celebA_train_1k/celebA_imgs/059835.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._059835.jpg
#   inflating: celebA_train_1k/celebA_imgs/105192.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105192.jpg
#   inflating: celebA_train_1k/celebA_imgs/135051.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._135051.jpg
#   inflating: celebA_train_1k/celebA_imgs/026039.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._026039.jpg
#   inflating: celebA_train_1k/celebA_imgs/115381.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._115381.jpg
#   inflating: celebA_train_1k/celebA_imgs/011695.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._011695.jpg
#   inflating: celebA_train_1k/celebA_imgs/000940.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000940.jpg
#   inflating: celebA_train_1k/celebA_imgs/061372.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._061372.jpg
#   inflating: celebA_train_1k/celebA_imgs/000798.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000798.jpg
#   inflating: celebA_train_1k/celebA_imgs/018869.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._018869.jpg
#   inflating: celebA_train_1k/celebA_imgs/078145.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._078145.jpg
#   inflating: celebA_train_1k/celebA_imgs/067065.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067065.jpg
#   inflating: celebA_train_1k/celebA_imgs/055969.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._055969.jpg
#   inflating: celebA_train_1k/celebA_imgs/025256.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._025256.jpg
#   inflating: celebA_train_1k/celebA_imgs/159821.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._159821.jpg
#   inflating: celebA_train_1k/celebA_imgs/138213.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._138213.jpg
#   inflating: celebA_train_1k/celebA_imgs/002831.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._002831.jpg
#   inflating: celebA_train_1k/celebA_imgs/004298.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._004298.jpg
#   inflating: celebA_train_1k/celebA_imgs/161366.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._161366.jpg
#   inflating: celebA_train_1k/celebA_imgs/037135.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._037135.jpg
#   inflating: celebA_train_1k/celebA_imgs/000799.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000799.jpg
#   inflating: celebA_train_1k/celebA_imgs/038206.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._038206.jpg
#   inflating: celebA_train_1k/celebA_imgs/000941.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000941.jpg
#   inflating: celebA_train_1k/celebA_imgs/001487.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._001487.jpg
#   inflating: celebA_train_1k/celebA_imgs/105193.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105193.jpg
#   inflating: celebA_train_1k/celebA_imgs/039118.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._039118.jpg
#   inflating: celebA_train_1k/celebA_imgs/125243.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._125243.jpg
#   inflating: celebA_train_1k/celebA_imgs/059834.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._059834.jpg
#   inflating: celebA_train_1k/celebA_imgs/131236.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._131236.jpg
#   inflating: celebA_train_1k/celebA_imgs/033353.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._033353.jpg
#   inflating: celebA_train_1k/celebA_imgs/075306.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._075306.jpg
#   inflating: celebA_train_1k/celebA_imgs/161401.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._161401.jpg
#   inflating: celebA_train_1k/celebA_imgs/150804.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._150804.jpg
#   inflating: celebA_train_1k/celebA_imgs/075460.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._075460.jpg
#   inflating: celebA_train_1k/celebA_imgs/002830.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._002830.jpg
#   inflating: celebA_train_1k/celebA_imgs/112389.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._112389.jpg
#   inflating: celebA_train_1k/celebA_imgs/123154.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._123154.jpg
#   inflating: celebA_train_1k/celebA_imgs/016845.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016845.jpg
#   inflating: celebA_train_1k/celebA_imgs/028773.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._028773.jpg
#   inflating: celebA_train_1k/celebA_imgs/076169.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._076169.jpg
#   inflating: celebA_train_1k/celebA_imgs/133347.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._133347.jpg
#   inflating: celebA_train_1k/celebA_imgs/152961.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._152961.jpg
#   inflating: celebA_train_1k/celebA_imgs/021025.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._021025.jpg
#   inflating: celebA_train_1k/celebA_imgs/016689.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016689.jpg
#   inflating: celebA_train_1k/celebA_imgs/067070.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067070.jpg
#   inflating: celebA_train_1k/celebA_imgs/027454.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._027454.jpg
#   inflating: celebA_train_1k/celebA_imgs/071612.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._071612.jpg
#   inflating: celebA_train_1k/celebA_imgs/026992.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._026992.jpg
#   inflating: celebA_train_1k/celebA_imgs/033421.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._033421.jpg
#   inflating: celebA_train_1k/celebA_imgs/025243.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._025243.jpg
#   inflating: celebA_train_1k/celebA_imgs/159834.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._159834.jpg
#   inflating: celebA_train_1k/celebA_imgs/063216.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._063216.jpg
#   inflating: celebA_train_1k/celebA_imgs/131544.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._131544.jpg
#   inflating: celebA_train_1k/celebA_imgs/012389.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._012389.jpg
#   inflating: celebA_train_1k/celebA_imgs/075312.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._075312.jpg
#   inflating: celebA_train_1k/celebA_imgs/149399.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._149399.jpg
#   inflating: celebA_train_1k/celebA_imgs/133435.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._133435.jpg
#   inflating: celebA_train_1k/celebA_imgs/124149.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._124149.jpg
#   inflating: celebA_train_1k/celebA_imgs/000955.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000955.jpg
#   inflating: celebA_train_1k/celebA_imgs/031550.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._031550.jpg
#   inflating: celebA_train_1k/celebA_imgs/068425.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._068425.jpg
#   inflating: celebA_train_1k/celebA_imgs/059820.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._059820.jpg
#   inflating: celebA_train_1k/celebA_imgs/125257.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._125257.jpg
#   inflating: celebA_train_1k/celebA_imgs/128983.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._128983.jpg
#   inflating: celebA_train_1k/celebA_imgs/091916.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._091916.jpg
#   inflating: celebA_train_1k/celebA_imgs/014908.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._014908.jpg
#   inflating: celebA_train_1k/celebA_imgs/073993.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._073993.jpg
#   inflating: celebA_train_1k/celebA_imgs/057825.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._057825.jpg
#   inflating: celebA_train_1k/celebA_imgs/028029.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._028029.jpg
#   inflating: celebA_train_1k/celebA_imgs/039124.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._039124.jpg
#   inflating: celebA_train_1k/celebA_imgs/050192.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._050192.jpg
#   inflating: celebA_train_1k/celebA_imgs/036571.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._036571.jpg
#   inflating: celebA_train_1k/celebA_imgs/047388.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._047388.jpg
#   inflating: celebA_train_1k/celebA_imgs/093867.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._093867.jpg
#   inflating: celebA_train_1k/celebA_imgs/020313.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._020313.jpg
#   inflating: celebA_train_1k/celebA_imgs/124607.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._124607.jpg
#   inflating: celebA_train_1k/celebA_imgs/046096.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._046096.jpg
#   inflating: celebA_train_1k/celebA_imgs/034366.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._034366.jpg
#   inflating: celebA_train_1k/celebA_imgs/033409.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._033409.jpg
#   inflating: celebA_train_1k/celebA_imgs/087812.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._087812.jpg
#   inflating: celebA_train_1k/celebA_imgs/022504.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._022504.jpg
#   inflating: celebA_train_1k/celebA_imgs/072327.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._072327.jpg
#   inflating: celebA_train_1k/celebA_imgs/024161.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._024161.jpg
#   inflating: celebA_train_1k/celebA_imgs/073039.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._073039.jpg
#   inflating: celebA_train_1k/celebA_imgs/129337.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._129337.jpg
#   inflating: celebA_train_1k/celebA_imgs/160051.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160051.jpg
#   inflating: celebA_train_1k/celebA_imgs/009795.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._009795.jpg
#   inflating: celebA_train_1k/celebA_imgs/144859.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._144859.jpg
#   inflating: celebA_train_1k/celebA_imgs/076627.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._076627.jpg
#   inflating: celebA_train_1k/celebA_imgs/079514.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._079514.jpg
#   inflating: celebA_train_1k/celebA_imgs/144681.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._144681.jpg
#   inflating: celebA_train_1k/celebA_imgs/000969.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000969.jpg
#   inflating: celebA_train_1k/celebA_imgs/050186.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._050186.jpg
#   inflating: celebA_train_1k/celebA_imgs/068419.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._068419.jpg
#   inflating: celebA_train_1k/celebA_imgs/126762.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._126762.jpg
#   inflating: celebA_train_1k/celebA_imgs/023168.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._023168.jpg
#   inflating: celebA_train_1k/celebA_imgs/156285.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._156285.jpg
#   inflating: celebA_train_1k/celebA_imgs/033390.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._033390.jpg
#   inflating: celebA_train_1k/celebA_imgs/013040.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._013040.jpg
#   inflating: celebA_train_1k/celebA_imgs/035939.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._035939.jpg
#   inflating: celebA_train_1k/celebA_imgs/141712.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141712.jpg
#   inflating: celebA_train_1k/celebA_imgs/106459.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._106459.jpg
#   inflating: celebA_train_1k/celebA_imgs/000982.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000982.jpg
#   inflating: celebA_train_1k/celebA_imgs/083335.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._083335.jpg
#   inflating: celebA_train_1k/celebA_imgs/135093.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._135093.jpg
#   inflating: celebA_train_1k/celebA_imgs/143105.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._143105.jpg
#   inflating: celebA_train_1k/celebA_imgs/021794.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._021794.jpg
#   inflating: celebA_train_1k/celebA_imgs/016138.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016138.jpg
#   inflating: celebA_train_1k/celebA_imgs/008306.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._008306.jpg
#   inflating: celebA_train_1k/celebA_imgs/010549.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._010549.jpg
#   inflating: celebA_train_1k/celebA_imgs/030699.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._030699.jpg
#   inflating: celebA_train_1k/celebA_imgs/145574.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._145574.jpg
#   inflating: celebA_train_1k/celebA_imgs/067919.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067919.jpg
#   inflating: celebA_train_1k/celebA_imgs/008460.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._008460.jpg
#   inflating: celebA_train_1k/celebA_imgs/123197.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._123197.jpg
#   inflating: celebA_train_1k/celebA_imgs/145212.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._145212.jpg
#   inflating: celebA_train_1k/celebA_imgs/085022.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._085022.jpg
#   inflating: celebA_train_1k/celebA_imgs/153470.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._153470.jpg
#   inflating: celebA_train_1k/celebA_imgs/043111.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._043111.jpg
#   inflating: celebA_train_1k/celebA_imgs/147405.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._147405.jpg
#   inflating: celebA_train_1k/celebA_imgs/025294.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._025294.jpg
#   inflating: celebA_train_1k/celebA_imgs/131593.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._131593.jpg
#   inflating: celebA_train_1k/celebA_imgs/035087.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._035087.jpg
#   inflating: celebA_train_1k/celebA_imgs/121958.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._121958.jpg
#   inflating: celebA_train_1k/celebA_imgs/147411.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._147411.jpg
#   inflating: celebA_train_1k/celebA_imgs/043105.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._043105.jpg
#   inflating: celebA_train_1k/celebA_imgs/023829.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._023829.jpg
#   inflating: celebA_train_1k/celebA_imgs/087621.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._087621.jpg
#   inflating: celebA_train_1k/celebA_imgs/157602.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._157602.jpg
#   inflating: celebA_train_1k/celebA_imgs/158531.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._158531.jpg
#   inflating: celebA_train_1k/celebA_imgs/088512.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._088512.jpg
#   inflating: celebA_train_1k/celebA_imgs/032924.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._032924.jpg
#   inflating: celebA_train_1k/celebA_imgs/037684.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._037684.jpg
#   inflating: celebA_train_1k/celebA_imgs/000028.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000028.jpg
#   inflating: celebA_train_1k/celebA_imgs/113040.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113040.jpg
#   inflating: celebA_train_1k/celebA_imgs/019579.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._019579.jpg
#   inflating: celebA_train_1k/celebA_imgs/058243.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._058243.jpg
#   inflating: celebA_train_1k/celebA_imgs/000996.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000996.jpg
#   inflating: celebA_train_1k/celebA_imgs/031593.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._031593.jpg
#   inflating: celebA_train_1k/celebA_imgs/058525.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._058525.jpg
#   inflating: celebA_train_1k/celebA_imgs/134399.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._134399.jpg
#   inflating: celebA_train_1k/celebA_imgs/095543.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._095543.jpg
#   inflating: celebA_train_1k/celebA_imgs/013054.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._013054.jpg
#   inflating: celebA_train_1k/celebA_imgs/141706.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141706.jpg
#   inflating: celebA_train_1k/celebA_imgs/107753.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._107753.jpg
#   inflating: celebA_train_1k/celebA_imgs/140418.jpg
# ...
#   inflating: celebA_train_1k/celebA_imgs/120264.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._120264.jpg
#   inflating: celebA_train_1k/celebA_imgs/055189.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._055189.jpg
#   inflating: celebA_train_1k/celebA_imgs/160640.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160640.jpg
#   inflating: celebA_train_1k/celebA_imgs/073628.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._073628.jpg
#   inflating: celebA_train_1k/celebA_imgs/022467.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._022467.jpg
#   inflating: celebA_train_1k/celebA_imgs/013862.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._013862.jpg
#   inflating: celebA_train_1k/celebA_imgs/129240.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._129240.jpg
#   inflating: celebA_train_1k/celebA_imgs/032674.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._032674.jpg
#   inflating: celebA_train_1k/celebA_imgs/136360.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._136360.jpg
#   inflating: celebA_train_1k/celebA_imgs/074621.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._074621.jpg
#   inflating: celebA_train_1k/celebA_imgs/042393.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._042393.jpg
#   inflating: celebA_train_1k/celebA_imgs/087971.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._087971.jpg
#   inflating: celebA_train_1k/celebA_imgs/120502.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._120502.jpg
#   inflating: celebA_train_1k/celebA_imgs/024016.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._024016.jpg
#   inflating: celebA_train_1k/celebA_imgs/052180.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._052180.jpg
#   inflating: celebA_train_1k/celebA_imgs/023779.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._023779.jpg
#   inflating: celebA_train_1k/celebA_imgs/034205.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._034205.jpg
#   inflating: celebA_train_1k/celebA_imgs/130711.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._130711.jpg
#   inflating: celebA_train_1k/celebA_imgs/098851.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._098851.jpg
#   inflating: celebA_train_1k/celebA_imgs/071759.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._071759.jpg
#   inflating: celebA_train_1k/celebA_imgs/069116.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._069116.jpg
#   inflating: celebA_train_1k/celebA_imgs/040584.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._040584.jpg
#   inflating: celebA_train_1k/celebA_imgs/082809.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._082809.jpg
#   inflating: celebA_train_1k/celebA_imgs/162725.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._162725.jpg
#   inflating: celebA_train_1k/celebA_imgs/039735.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._039735.jpg
#   inflating: celebA_train_1k/celebA_imgs/160132.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160132.jpg
#   inflating: celebA_train_1k/celebA_imgs/121608.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._121608.jpg
#   inflating: celebA_train_1k/celebA_imgs/087965.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._087965.jpg
#   inflating: celebA_train_1k/celebA_imgs/138359.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._138359.jpg
#   inflating: celebA_train_1k/celebA_imgs/034211.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._034211.jpg
#   inflating: celebA_train_1k/celebA_imgs/062731.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._062731.jpg
#   inflating: celebA_train_1k/celebA_imgs/151489.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._151489.jpg
#   inflating: celebA_train_1k/celebA_imgs/160654.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160654.jpg
#   inflating: celebA_train_1k/celebA_imgs/113862.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113862.jpg
#   inflating: celebA_train_1k/celebA_imgs/152180.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._152180.jpg
#   inflating: celebA_train_1k/celebA_imgs/079477.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._079477.jpg
#   inflating: celebA_train_1k/celebA_imgs/048872.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._048872.jpg
#   inflating: celebA_train_1k/celebA_imgs/046687.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._046687.jpg
#   inflating: celebA_train_1k/celebA_imgs/057952.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._057952.jpg
#   inflating: celebA_train_1k/celebA_imgs/142393.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._142393.jpg
#   inflating: celebA_train_1k/celebA_imgs/102984.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._102984.jpg
#   inflating: celebA_train_1k/celebA_imgs/155604.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._155604.jpg
#   inflating: celebA_train_1k/celebA_imgs/018076.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._018076.jpg
#   inflating: celebA_train_1k/celebA_imgs/142378.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._142378.jpg
#   inflating: celebA_train_1k/celebA_imgs/000639.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000639.jpg
#   inflating: celebA_train_1k/celebA_imgs/019368.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._019368.jpg
#   inflating: celebA_train_1k/celebA_imgs/105033.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._105033.jpg
#   inflating: celebA_train_1k/celebA_imgs/026198.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._026198.jpg
#   inflating: celebA_train_1k/celebA_imgs/098110.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._098110.jpg
#   inflating: celebA_train_1k/celebA_imgs/005741.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._005741.jpg
#   inflating: celebA_train_1k/celebA_imgs/043714.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._043714.jpg
#   inflating: celebA_train_1k/celebA_imgs/053507.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._053507.jpg
#   inflating: celebA_train_1k/celebA_imgs/141671.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141671.jpg
#   inflating: celebA_train_1k/celebA_imgs/139912.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._139912.jpg
#   inflating: celebA_train_1k/celebA_imgs/151462.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._151462.jpg
#   inflating: celebA_train_1k/celebA_imgs/004339.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._004339.jpg
#   inflating: celebA_train_1k/celebA_imgs/137081.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._137081.jpg
#   inflating: celebA_train_1k/celebA_imgs/141117.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141117.jpg
#   inflating: celebA_train_1k/celebA_imgs/091134.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._091134.jpg
#   inflating: celebA_train_1k/celebA_imgs/097545.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._097545.jpg
#   inflating: celebA_train_1k/celebA_imgs/101533.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._101533.jpg
#   inflating: celebA_train_1k/celebA_imgs/031382.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._031382.jpg
#   inflating: celebA_train_1k/celebA_imgs/112229.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._112229.jpg
#   inflating: celebA_train_1k/celebA_imgs/017423.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._017423.jpg
#   inflating: celebA_train_1k/celebA_imgs/060873.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._060873.jpg
#   inflating: celebA_train_1k/celebA_imgs/124957.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._124957.jpg
#   inflating: celebA_train_1k/celebA_imgs/016729.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016729.jpg
#   inflating: celebA_train_1k/celebA_imgs/155176.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._155176.jpg
#   inflating: celebA_train_1k/celebA_imgs/051462.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._051462.jpg
#   inflating: celebA_train_1k/celebA_imgs/152619.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._152619.jpg
#   inflating: celebA_train_1k/celebA_imgs/118076.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._118076.jpg
#   inflating: celebA_train_1k/celebA_imgs/141103.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141103.jpg
#   inflating: celebA_train_1k/celebA_imgs/127286.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._127286.jpg
#   inflating: celebA_train_1k/celebA_imgs/108265.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._108265.jpg
#   inflating: celebA_train_1k/celebA_imgs/158452.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._158452.jpg
#   inflating: celebA_train_1k/celebA_imgs/106248.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._106248.jpg
#   inflating: celebA_train_1k/celebA_imgs/130922.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._130922.jpg
#   inflating: celebA_train_1k/celebA_imgs/005033.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._005033.jpg
#   inflating: celebA_train_1k/celebA_imgs/147572.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._147572.jpg
#   inflating: celebA_train_1k/celebA_imgs/012229.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._012229.jpg
#   inflating: celebA_train_1k/celebA_imgs/035696.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._035696.jpg
#   inflating: celebA_train_1k/celebA_imgs/034588.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._034588.jpg
#   inflating: celebA_train_1k/celebA_imgs/141665.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141665.jpg
#   inflating: celebA_train_1k/celebA_imgs/151476.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._151476.jpg
#   inflating: celebA_train_1k/celebA_imgs/041117.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._041117.jpg
#   inflating: celebA_train_1k/celebA_imgs/079488.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._079488.jpg
#   inflating: celebA_train_1k/celebA_imgs/123786.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._123786.jpg
#   inflating: celebA_train_1k/celebA_imgs/113645.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._113645.jpg
#   inflating: celebA_train_1k/celebA_imgs/018062.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._018062.jpg
#   inflating: celebA_train_1k/celebA_imgs/001533.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._001533.jpg
#   inflating: celebA_train_1k/celebA_imgs/080763.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._080763.jpg
#   inflating: celebA_train_1k/celebA_imgs/052625.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._052625.jpg
#   inflating: celebA_train_1k/celebA_imgs/146122.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._146122.jpg
#   inflating: celebA_train_1k/celebA_imgs/010416.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._010416.jpg
#   inflating: celebA_train_1k/celebA_imgs/059770.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._059770.jpg
#   inflating: celebA_train_1k/celebA_imgs/046650.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._046650.jpg
#   inflating: celebA_train_1k/celebA_imgs/000605.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000605.jpg
#   inflating: celebA_train_1k/celebA_imgs/049563.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049563.jpg
#   inflating: celebA_train_1k/celebA_imgs/040547.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._040547.jpg
#   inflating: celebA_train_1k/celebA_imgs/019432.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._019432.jpg
#   inflating: celebA_train_1k/celebA_imgs/047228.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._047228.jpg
#   inflating: celebA_train_1k/celebA_imgs/154240.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._154240.jpg
#   inflating: celebA_train_1k/celebA_imgs/112215.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._112215.jpg
#   inflating: celebA_train_1k/celebA_imgs/046136.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._046136.jpg
#   inflating: celebA_train_1k/celebA_imgs/092401.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._092401.jpg
#   inflating: celebA_train_1k/celebA_imgs/000163.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000163.jpg
#   inflating: celebA_train_1k/celebA_imgs/049205.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049205.jpg
#   inflating: celebA_train_1k/celebA_imgs/059016.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._059016.jpg
#   inflating: celebA_train_1k/celebA_imgs/100611.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._100611.jpg
#   inflating: celebA_train_1k/celebA_imgs/004305.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._004305.jpg
#   inflating: celebA_train_1k/celebA_imgs/052143.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._052143.jpg
#   inflating: celebA_train_1k/celebA_imgs/015208.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._015208.jpg
#   inflating: celebA_train_1k/celebA_imgs/157749.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._157749.jpg
#   inflating: celebA_train_1k/celebA_imgs/099540.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._099540.jpg
#   inflating: celebA_train_1k/celebA_imgs/014102.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._014102.jpg
#   inflating: celebA_train_1k/celebA_imgs/098886.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._098886.jpg
#   inflating: celebA_train_1k/celebA_imgs/109147.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._109147.jpg
#   inflating: celebA_train_1k/celebA_imgs/000177.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000177.jpg
#   inflating: celebA_train_1k/celebA_imgs/082606.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._082606.jpg
#   inflating: celebA_train_1k/celebA_imgs/010364.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._010364.jpg
#   inflating: celebA_train_1k/celebA_imgs/050998.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._050998.jpg
#   inflating: celebA_train_1k/celebA_imgs/067852.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._067852.jpg
#   inflating: celebA_train_1k/celebA_imgs/000611.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._000611.jpg
#   inflating: celebA_train_1k/celebA_imgs/046644.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._046644.jpg
#   inflating: celebA_train_1k/celebA_imgs/057991.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._057991.jpg
#   inflating: celebA_train_1k/celebA_imgs/049577.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._049577.jpg
#   inflating: celebA_train_1k/celebA_imgs/016073.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._016073.jpg
#   inflating: celebA_train_1k/celebA_imgs/077499.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._077499.jpg
#   inflating: celebA_train_1k/celebA_imgs/029283.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._029283.jpg
#   inflating: celebA_train_1k/celebA_imgs/150754.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._150754.jpg
#   inflating: celebA_train_1k/celebA_imgs/160697.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._160697.jpg
#   inflating: celebA_train_1k/celebA_imgs/086306.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._086306.jpg
#   inflating: celebA_train_1k/celebA_imgs/141659.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._141659.jpg
#   inflating: celebA_train_1k/celebA_imgs/081469.jpg
#   inflating: __MACOSX/celebA_train_1k/celebA_imgs/._081469.jpg

# %% [markdown]
# Let's look at the data first:

# %%
! ls celebA_train_1k/
# Out:
# celebA_anno.txt  celebA_imgs  celebA_train_split.txt

# %% [markdown]
# - celebA_imgs — folder with aligned images
# - celebA_anno.txt — file with annotations: which person each image corresponds to
# - celebA_train_split.txt — file with train/val/test info

# %%
import os
import cv2
import numpy as np
from PIL import Image
from skimage import io, transform

import torch

import torchvision.transforms as transforms
from torch.utils.data import Dataset

import matplotlib.pyplot as plt

# %%
def show_imgs(images_names):
    imgs = []
    for img in images_names:
      img = Image.open(os.path.join('celebA_train_1k/celebA_imgs/', img))
      imgs.append(np.array(img))

    f, axes= plt.subplots(1, len(imgs), figsize=(3*len(imgs),5))
    for i, axis in enumerate(axes):
        axes[i].imshow(imgs[i], cmap='gray')
        axes[i].set_title(images_names[i])
    plt.show()

images_names = os.listdir('./celebA_train_1k/celebA_imgs/')[:5]
show_imgs(images_names)

# %% [markdown]
# ### Train Neural Network

# %% [markdown]
# Let's build a Datasets and network using this images:

# %%
def get_paths(dataset_type='train'):
    '''
    a function that returnes list of images paths for a given type of the dataset
    params:
      dataset_type: one of 'train', 'val', 'test'
    '''

    labels_dict = {
        'train': 0,
        'val': 1,
        'test': 2,
    }

    f = open('celebA_train_1k/celebA_train_split.txt', 'r')
    lines = f.readlines()
    f.close()

    lines = [x.strip().split() for x in lines]
    lines = [x[0] for x in lines if int(x[1]) == labels_dict[dataset_type]]

    images_paths = []
    for filename in lines:            
        images_paths.append(os.path.join('celebA_train_1k/celebA_imgs/', filename))
    
    return np.array(images_paths)


class celebADataset(Dataset):
    """Feel free to rewrite it. For ex. cache all images in RAM to increase training speed"""
    def __init__(self, dataset_type, transform, aug=None,):
        self.images = get_paths(dataset_type=dataset_type)

        f = open('celebA_train_1k/celebA_anno.txt', 'r')
        labels = f.readlines()
        f.close()
        labels = [x.strip().split() for x in labels]
        labels = {x:int(y) for x, y in labels}
        self.labels = [labels[x.split('/')[-1]] for x in self.images]

        self.transform = transform
        self.aug = aug
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):        
        img_name = self.images[idx]
        label = self.labels[idx]
        
        image = Image.open(img_name) 
        
        if self.aug:
            sample = self.aug(
                image=image,
            )
        else:
            sample = {
                'image': image,
                'label': label,
            }
        
        sample['image'] = self.transform(sample['image'])

        return sample

# %%
transform = transforms.Compose([
      # you may add anything, e.g. augmentation
      transforms.Resize(160),
      transforms.ToTensor(),
      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

train_data = celebADataset('train', transform)
val_data = celebADataset('val', transform)
test_data = celebADataset('test', transform)

# choose your own batch_size
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %% [markdown]
# We'll use pretrained on VGGFace2 network InceptionResnetV1 from here: https://github.com/timesler/facenet-pytorch/tree/master/models

# %%
# !git clone https://github.com/timesler/facenet-pytorch.git
# !mv facenet-pytorch/models ./
# Out:
# Cloning into 'facenet-pytorch'...
# remote: Enumerating objects: 1267, done.
# remote: Total 1267 (delta 0), reused 0 (delta 0), pack-reused 1267
# Receiving objects: 100% (1267/1267), 22.88 MiB | 25.41 MiB/s, done.
# Resolving deltas: 100% (619/619), done.

# %%
! ls models
# Out:
# inception_resnet_v1.py	mtcnn.py  utils

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
from models import inception_resnet_v1
model = inception_resnet_v1.InceptionResnetV1(pretrained='vggface2', classify=True, num_classes = 1000).to(device)

# %%
import torch, torch.nn as nn
model.logits = nn.Linear(model.logits.in_features, 1000)

# %% [markdown]
# **Workflow**: fine-tune a model on train_data using val_data for validation.Use standard CE loss.  Calculate the loss and accuracy on test set after training.
#
# You may use any optimizer you want and any learning rate. It is also beneficial to freeze starting layers to boost training speed and avoid overfitting.
#
# **To get the whole mark for this section you need to achieve 80% accuracy on test set**.

# %%
for param in model.parameters():
    param.requires_grad = True

# %%
i=0
for param in model.parameters():
    i+=1
    param.requires_grad = False
    if i==300:      
      break
print(i)
# Out:
# 300

# %%
# Out:
# tensor([155, 154, 829, 509, 565, 273, 300,  35, 476, 528, 789, 851, 149, 837,
#         280, 131,  79, 377,   2, 759, 620, 667, 307, 110, 854, 788,  50, 897,
#         657, 535, 178, 230, 823, 850, 714, 112, 866,  13, 149,  45, 371, 279,
#         677, 588, 829, 780,  95, 834, 752, 169, 352, 953, 407, 323, 983, 920,
#         380, 809, 882, 162, 511, 244, 889, 957])

# %% [markdown]
# **Cosine similarity calculation**: drop a last layer of trained network. Get embeddings for some images from train set and for images from test set. Calculate cosine similarities between embeddings corresponding to the pictures of the same person and different people. Is the difference big in any of cases?

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

import torch.nn.functional as F
from sklearn.metrics import accuracy_score
import torch.optim as optim

optimizer =  optim.AdamW(model.parameters(), lr=1e-4)# favourite one
criterion = nn.CrossEntropyLoss()

epochs = 15
clip = 1.5
alpha_c =1
train_history=[]
valid_history  = []
acc_history =[]
best_valid_loss = float('inf')
model.to(device)
for epoch in range(epochs):
  print(f"Start eposh #{epoch}")
  model.train()
  history = []
  i=0

  train_loss =0

  for train_batch in train_loader:

    images= torch.tensor(train_batch['image']).to(device)

    label = torch.tensor(train_batch['label']).to(device)
   
  
    output= model(images)

    optimizer.zero_grad()
   
    loss = criterion(output,label)

    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
    optimizer.step()
    train_loss+=loss
      
    i+=1
  train_history.append(train_loss.detach().cpu().numpy()/i)
 
  model.eval()
  bath_size =0 
  val_loss=0
  
  acc = []

  for valid_batch in val_loader:
    images= torch.tensor(valid_batch['image']).to(device)
    label = torch.tensor(valid_batch['label']).to(device)

    output = model(images)
    loss = criterion(output,label)
    val_loss+=loss
    bath_size+=1
    output  = torch.argmax(output, axis=1).cpu().detach().numpy()
    acc.append(accuracy_score(output,label.cpu().detach().numpy() ) )
  acc_history.append(np.array(acc).mean())
  valid_history.append(val_loss.detach().cpu().numpy()/bath_size)

  if True:
        plt.figure(figsize=(10, 10))
        clear_output(True)
        plt.plot(train_history, label='train loss')
        plt.plot(valid_history, label='val loss')
        plt.legend()    
        plt.show()

        plt.figure(figsize=(10, 10))
        plt.plot(acc_history, label='val acc')
        plt.legend()    
        plt.show()



  if val_loss < best_valid_loss:
        best_valid_loss = val_loss
        torch.save(model.state_dict(), '/content/gdrive/MyDrive/Colab Notebooks/project dls/best-val-model.pt')

  print(f"End eposh #{epoch}")
# Out:
# End eposh #14

# %%
model.load_state_dict(torch.load('/content/gdrive/MyDrive/Colab Notebooks/project dls/best-val-model.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Cosine similarity distribution**: calculate all the cosine similarities between images in test dataset and train dataset of the same person. This means if you have image of person #106 in test dataset, calculate all similarities between this person's embeddings from test dataset and this person's embeddings from train dataset.
#
# Then also do that for pairs of different people. This means if you have image of person #106 in test dataset, calculate similarities between this person's embeddings from test dataset and other people embeddings from train dataset.
#
# This calculation may take a long time and memory since it's a lot of pairs. You can cut the number of pairs which you calculate distances between up to 5k, as an example.

# %%
[x[0] for x in filter(lambda x: x[1] >=20, Counter(train_data.labels).items())]

# %%
from sklearn.metrics import accuracy_score
def Test_acc(model,test_loader ):
  acc = []
  for batch in test_loader:
    model.eval()
    images= torch.tensor(batch['image']).to(device)
    label = torch.tensor(batch['label']).cpu().detach().numpy()
    output = model(images)
    output  = torch.argmax(output, axis=1).cpu().detach().numpy()
    acc.append(accuracy_score(output,label ) )
  return np.array(acc).mean()
  
Test_acc(model,test_loader )

# %%
def get_embeddings(model, loader):
    model.eval()
    embeddings = list()
    targets = list()
    model.to(device)
    with torch.no_grad():
        for data in loader:
            inputs = torch.tensor(data['image']).to(device)
            labels = torch.tensor(data['label']).to(device)
            model_emb = torch.nn.Sequential(*(list(model.children())[:-3]))
            
            output =model_emb(inputs)
        
            embeddings.append(output.detach().cpu())
            targets.append(labels.data.cpu())
        
    return torch.cat(embeddings).numpy(), torch.cat(targets).numpy()

# %%
train_emb, train_label_emb = get_embeddings(model, train_loader)
test_emb, test_label_emb = get_embeddings(model, test_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
import pandas as pd
from collections import Counter
def get_distance(x, y=None, index=None, columns=None, metric='cosine'):
    if metric == 'cosine':
        distance = cosine_similarity(x, y)
    elif metric == 'euclidean':
        distance = euclidean_distances(x, y)
    return pd.DataFrame(distance, index=index, columns=columns)
# select labels with 20 or more instances in train dataset
filtered_labels = [x[0] for x in filter(lambda x: x[1] >=20, Counter(train_data.labels).items())]

# get indices of selected labels
test_inds = np.in1d(test_data.labels, filtered_labels).nonzero()[0]
train_inds = np.in1d(train_data.labels, filtered_labels).nonzero()[0]
print(f'TEST instances: {len(test_inds)}, TRAIN instances: {len(train_inds)}')

# calculate cosine similarities between test embeddings and train embeddings
pos_neg_matrix = get_distance(x=train_emb[train_inds].squeeze(2).squeeze(2), y=test_emb[test_inds].squeeze(2).squeeze(2), index=train_label_emb[train_inds], columns=test_label_emb[test_inds])
pos_sim = list()
neg_sim = list()

for label in np.unique(pos_neg_matrix.columns):
     pos_sim.extend(pos_neg_matrix.iloc[pos_neg_matrix.index == label, pos_neg_matrix.columns == label].values.flatten())
     neg_sim.extend(pos_neg_matrix.iloc[pos_neg_matrix.index != label, pos_neg_matrix.columns == label].values.flatten())
title_text = 'Histogram of Cosine similarity distribution for all labels (train vs. test)'
    
fig = plt.figure(figsize=(12, 6))
weights_pos = np.ones_like(pos_sim) / len(pos_sim)
weights_neg = np.ones_like(neg_sim) / len(neg_sim)
plt.hist(pos_sim, label='positive', weights=weights_pos, alpha=0.5, bins= 30)
plt.hist(neg_sim, label='negative', weights=weights_neg, alpha=0.5, bins= 30)
plt.legend()
plt.xlabel('Cosine similarity', fontsize=12)

plt.title(title_text, fontsize=16)
plt.show()
# Out:
# TEST instances: 1856, TRAIN instances: 9718

# %% [markdown]
# ## Task 2 (20% points): Identificaton rate metric

# %% [markdown]
# When training the model above we used CE loss on val and test set as a measure of performance of our model. But this has a major disadvantage: we can't measure how godd a model would work on unseen faces (which are not present in training, val & test sets)
#
# To address this we can calculate another metric for the model: **identification rate**. This is how it works:
#
# We have two sets of faces: query and distractors. None of the faces from those sets are present in train, val or test sets.
#
# 1. calculate cosine similarities between all the faces corresponding to the same people from query dataset. This means if the person has 3 photos in query part: 01.jpg, 02.jpg, 03.jpg, then calculate 3 cosine similarities between every pair of embeddings corresponding to those photos.
# 2. calculate cosine similarities between all the faces corresponding to the different people from query dataset.
# 3. calculate cosine similarities between all the pairs of embeddings corresponding to query and distractors. This means calculate similarities between pairs (q, d), where q is the embedding that corresponds to a face from query, d — embedding that corresponds to a face from distractors. You'll get |query|*|distractors| similarities.
# 4. Sum numbers of similarities from 2 and 3 stages. This is a number of false pairs.
# 5. fix **FPR** (false positive rate). Let it be 0.01 in our case. FPR multiplied by a number of false pairs from the stage 4 is the number of false positives we would allow our model to make. Let's call this number N
# 6. Sort all the similarities of false pairs by descending order. Get the Nth element from the beginning — that's our **threshold similarity**.
# 7. Calculate how many positive similarities from stage 1 are equal or more that threshold. Divide this number by whole number of positive similarities from stage 1. This is TPR (true positive rate) — our metric.
#
# This metric can also be expressed as TPR@FPR=0.01. FPR can vary.

# %% [markdown]
# Datasets (query photos, query labels & distructors photos) you can download from here: https://disk.yandex.ru/d/C54mClLmQkag6Q

# %% [markdown]
# **Task**: implement the TPR@FPR metric. Calculate it for your model and test dataset on FPR=[0.5, 0.2, 0.1, 0.05].
#
# There're some functions pre-defined and some tests given for better understanding. Please don't change the functions prototypes, so that you can use asserts for checking.

# %%
! unzip /content/gdrive/MyDrive/data/celebA_ir.zip

# %%
from collections import defaultdict

# file with query part annotations: which image belongs to which class
# format: 
#     image_name_1.jpg 2678
#     image_name_2.jpg 2679
f = open('./celebA_ir/celebA_anno_query.txt', 'r')
query_lines = f.readlines()
f.close()
query_lines = [x.strip().split() for x in query_lines]
# plain list of image names from query. Neede to compute embeddings for query
query_img_names = [x[0] for x in query_lines]

# dictionary with info of which images from query belong to which class
# format:
#     {class: [image_1, image_2, ...]}
query_dict = defaultdict(list)
for img_name, img_class in query_lines:
  query_dict[img_class].append(img_name)

# list of distractor images
distractors_img_names = os.listdir('./celebA_ir/celebA_distractors')

# %%
query_dict

# %%
query_img_names

# %%
class DatasetQuery(Dataset):
    """Feel free to rewrite it. For ex. cache all images in RAM to increase training speed"""
    def __init__(self, query_lines,query_img_names,query_dict, transform):
        self.images = query_img_names
        self.labels = query_dict

        self.transform = transform
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):        
        img_name = self.images[idx]
        label = self.labels[idx]
        image = Image.open(f'./celebA_ir/celebA_query/{ img_name }') 
        
        sample = {
                'image': image,
                'label': label,
            }
        
        sample['image'] = self.transform(sample['image'])

        return sample

# %%
transform = transforms.Compose([
      # you may add anything, e.g. augmentation
      transforms.Resize(160),
      transforms.ToTensor(),
      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])
data = DatasetQuery(query_lines,query_img_names,query_dict, transform)
loader_query = torch.utils.data.DataLoader(data, batch_size= 64, shuffle=False)

# %%
class DatasetDistractors(Dataset):
    def __init__(self, distractors_img_names, transform):
        self.images = distractors_img_names 
        self.transform = transform
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):        
        img_name = self.images[idx]

        image = Image.open(f'/content/celebA_ir/celebA_distractors/{ img_name }') 
        
        sample = {
                'image': image,
            }
        
        sample['image'] = self.transform(sample['image'])

        return sample

# %%
data = DatasetDistractors(distractors_img_names,transform)
loader_distractors = torch.utils.data.DataLoader(data, batch_size= 64, shuffle=False)

# %%
def compute_embeddings(model, loader):
  '''
  compute embeddings from the trained model for list of images.
  params:
    model: trained nn model that takes images and outputs embeddings
     loader: list of images paths to compute embeddings for
  output:
    list: list of model embeddings. Each embedding corresponds to images 
          names from images_list

  '''

  model.eval()
  embeddings = list()
  model.to(device)
  with torch.no_grad():
        for batch in loader:
            inputs = torch.tensor(batch ['image']).to(device)
            model_emb = torch.nn.Sequential(*(list(model.children())[:-3]))        
            output =model_emb(inputs)     
            embeddings.append(output.detach().cpu())


  return embeddings
  raise NotImplementedError

# %%
query_embeddings = compute_embeddings(model, loader_query)
distractors_embeddings = compute_embeddings(model, loader_distractors )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
filtered_labels = [x[0] for x in filter(lambda x: x[1] >=20, Counter(train_data.labels).items())]

# get indices of selected labels
test_inds = np.in1d(test_data.labels, filtered_labels).nonzero()[0]
train_inds = np.in1d(train_data.labels, filtered_labels).nonzero()[0]
print(f'TEST instances: {len(test_inds)}, TRAIN instances: {len(train_inds)}')

# calculate cosine similarities between test embeddings and train embeddings
pos_neg_matrix = get_distance(x=train_emb[train_inds].squeeze(2).squeeze(2), y=test_emb[test_inds].squeeze(2).squeeze(2), index=train_label_emb[train_inds], columns=test_label_emb[test_inds])
pos_sim = list()
neg_sim = list()

for label in np.unique(pos_neg_matrix.columns):
     pos_sim.extend(pos_neg_matrix.iloc[pos_neg_matrix.index == label, pos_neg_matrix.columns == label].values.flatten())
     neg_sim.extend(pos_neg_matrix.iloc[pos_neg_matrix.index != label, pos_neg_matrix.columns == label].values.flatten())
title_text = 'Histogram of Cosine similarity distribution for all labels (train vs. test)'
    
fig = plt.figure(figsize=(12, 6))
weights_pos = np.ones_like(pos_sim) / len(pos_sim)
weights_neg = np.ones_like(neg_sim) / len(neg_sim)
plt.hist(pos_sim, label='positive', weights=weights_pos, alpha=0.5, bins= 30)
plt.hist(neg_sim, label='negative', weights=weights_neg, alpha=0.5, bins= 30)
plt.legend()
plt.xlabel('Cosine similarity', fontsize=12)

plt.title(title_text, fontsize=16)
plt.show()

# %%
def compute_cosine_query_pos(query_dict, query_img_names, query_embeddings):
  '''
  compute cosine similarities between positive pairs from query (stage 1)
  params:
    query_dict: dict {class: [image_name_1, image_name_2, ...]}. Key: class in 
                the dataset. Value: images corresponding to that class
    query_img_names: list of images names
    query_embeddings: list of embeddings corresponding to query_img_names
  output:
    list of floats: similarities between embeddings corresponding 
                    to the same people from query list
  '''

  raise NotImplementedError

def compute_cosine_query_neg(query_dict, query_img_names, query_embeddings):
  '''
  compute cosine similarities between negative pairs from query (stage 2)
  params:
    query_dict: dict {class: [image_name_1, image_name_2, ...]}. Key: class in 
                the dataset. Value: images corresponding to that class
    query_img_names: list of images names
    query_embeddings: list of embeddings corresponding to query_img_names
  output:
    list of floats: similarities between embeddings corresponding 
                    to different people from query list
  '''

  raise NotImplementedError

def compute_cosine_query_distractors(query_embeddings, distractors_embeddings):
  '''
  compute cosine similarities between negative pairs from query and distractors
  (stage 3)
  params:
    query_embeddings: list of embeddings corresponding to query_img_names
    distractors_embeddings: list of embeddings corresponding to distractors_img_names
  output:
    list of floats: similarities between pairs of people (q, d), where q is 
                    embedding corresponding to photo from query, d —
                    embedding corresponding to photo from distractors
  '''

  raise NotImplementedError

# %%
cosine_query_pos = compute_cosine_query_pos(query_dict, query_img_names, 
                                            query_embeddings)
cosine_query_neg = compute_cosine_query_neg(query_dict, query_img_names, 
                                            query_embeddings)
cosine_query_distractors = compute_cosine_query_distractors(query_embeddings, 
                                                            distractors_embeddings)

# %% [markdown]
# Check you code of functions which compute similarities:

# %%
test_query_dict = {
    2876: ['1.jpg', '2.jpg', '3.jpg'],
    5674: ['5.jpg'],
    864:  ['9.jpg', '10.jpg'],
}
test_query_img_names = ['1.jpg', '2.jpg', '3.jpg', '5.jpg', '9.jpg', '10.jpg']
test_query_embeddings = [
                    [1.56, 6.45,  -7.68],
                    [-1.1 , 6.11,  -3.0],
                    [-0.06,-0.98,-1.29],
                    [8.56, 1.45,  1.11],
                    [0.7,  1.1,   -7.56],
                    [0.05, 0.9,   -2.56],
]

test_distractors_img_names = ['11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg']

test_distractors_embeddings = [
                    [0.12, -3.23, -5.55],
                    [-1,   -0.01, 1.22],
                    [0.06, -0.23, 1.34],
                    [-6.6, 1.45,  -1.45],
                    [0.89,  1.98, 1.45],
]

test_cosine_query_pos = compute_cosine_query_pos(test_query_dict, test_query_img_names, 
                                            test_query_embeddings)
test_cosine_query_neg = compute_cosine_query_neg(test_query_dict, test_query_img_names, 
                                            test_query_embeddings)
test_cosine_query_distractors = compute_cosine_query_distractors(test_query_embeddings, 
                                                            test_distractors_embeddings)

# %%
true_cosine_query_pos = [0.8678237233650096, 0.21226104378511604,
                         -0.18355866977496182, 0.9787437979250561]
assert np.allclose(sorted(test_cosine_query_pos), sorted(true_cosine_query_pos)), \
      "A mistake in compute_cosine_query_pos function"

true_cosine_query_neg = [0.15963231223161822, 0.8507997093616965, 0.9272761484302097,
                         -0.0643994061127092, 0.5412660901220571, 0.701307100338029,
                         -0.2372575528216902, 0.6941032794522218, 0.549425446066643,
                         -0.011982733001947084, -0.0466679194884999]
assert np.allclose(sorted(test_cosine_query_neg), sorted(true_cosine_query_neg)) \
      "A mistake in compute_cosine_query_neg function"

true_cosine_query_distractors = [0.3371426578637511, -0.6866465610863652, -0.8456563512871669,
                                 0.14530087113136106, 0.11410510307646118, -0.07265097629002357,
                                 -0.24097699660707042,-0.5851992679925766, 0.4295494455718534,
                                 0.37604478596058194, 0.9909483738948858, -0.5881093317868022,
                                 -0.6829712976642919, 0.07546364489032083, -0.9130970963915521,
                                 -0.17463101988684684, -0.5229363015558941, 0.1399896725311533,
                                 -0.9258034013399499, 0.5295114163723346, 0.7811585442749943,
                                 -0.8208760031249596, -0.9905139680301821, 0.14969764653247228,
                                 -0.40749654525418444, 0.648660814944824, -0.7432584300096284,
                                 -0.9839696492435877, 0.2498741082804709, -0.2661183373780491]
assert np.allclose(sorted(test_cosine_query_distractors), sorted(true_cosine_query_distractors)), \
      "A mistake in compute_cosine_query_distractors function"

# %% [markdown]
# Implement the final function: identification rate calculation

# %%
def compute_ir(cosine_query_pos, cosine_query_neg, cosine_query_distractors, 
               fpr=0.1):
  '''
  compute identification rate using precomputer cosine similarities between pairs
  at given fpr
  params:
    cosine_query_pos: cosine similarities between positive pairs from query
    cosine_query_neg: cosine similarities between negative pairs from query
    cosine_query_distractors: cosine similarities between negative pairs 
                              from query and distractors
    fpr: false positive rate at which to compute TPR
  output: 
    float: threshold for given fpr 
    float: TPR at given FPR
  '''
  # YOUR CODE HERE
  pass

# %% [markdown]
# Check yourself:

# %%
test_thr = []
test_tpr = []
for fpr in [0.5, 0.3, 0.1]:
  x, y = compute_ir(test_cosine_query_pos, test_cosine_query_neg, 
                    test_cosine_query_distractors, fpr=fpr)
  thr.append(x)
  tpr.append(y)

# %%
true_thr = [-0.011982733001947084, 0.3371426578637511, 0.701307100338029]
assert np.allclose(np.array(thr), np.array(true_thr)), "A mistake in computing threshold"

true_tpr = [0.75, 0.5, 0.5]
assert np.allclose(np.array(tpr), np.array(true_tpr)), "A mistake in computing tpr"

# %% [markdown]
# Finally compute tpr for faces query and distractors dataset and fpr = [0.5, 0.2, 0.1, 0.05]:

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 3 (50% points): Loss functions

# %% [markdown]
# Building a network on task 1 we used an ordinary CE loss. But there are many more variants of loss functions that can be used to train neural network. We will discuss two of them, which are the most popular. More examples of losses for face recognition and their performance reviews you can find in this paper: https://arxiv.org/pdf/1901.05903.pdf

# %% [markdown]
# ### TripletLoss (25% points)

# %% [markdown]
# This is another kind of loss which does not require a model to have last classification layer — it works directly with embeddings. It requires by design to make embeddings of one person be close on embeddings space and embeddings of different people be far away from each other.
#
# This loss has an advantage over CE-like losses: it does not rely on number of classes in dataset. If we have new faces of new people in a dataset, we won't need to completely retrain the network, we could just fine-tune the trained network on new photos.

# %% [markdown]
# **How TripletLoss works**:
#
# Here the architecture of neural network will be slightly different than it was when we used CE loss: it won't have the last classification layer. The last layer of NN will output embeddings of the given photo.

# %% [markdown]
# ![Screenshot 2021-11-04 at 22.15.41.png](data:image/png;base64,...)

# %% [markdown]
# The TripletLoss function works directly with these embeddings. The idea of it is to make embeddings of the same people more close, compact in the embedding space, and the embeddings of the different people be more separate. There's a formula for the loss:
#
# $$L(e, p, n) = max\{d(a, p) - d(a, n) + margin, 0\},$$
#
# where
# - $e$ is embedding of a photo (output of a model)
# - $p$ is a positive embedding for the photo (embedding that we want $e$ be close to)
# - $n$ is a negative embedding for the photo (embedding that we want $e$ be far from)
# - $d(x, y)$ is a distance measure between embeddings
# - margin — a positive margin to further boost the difference between $d(a, p)$ and $d(a, n)$
#
# **All the embeddings $e$, $p$ and $n$ must be normalized before passing them to the loss**.
#
# In our case for the given photo $E$ and it's embedding $e$ positive embedding $p$ must be an embedding of the photo of the same person and embedding $n$ must be an ambedding of the photo of the different person.
#
# This emplementation of TripletLoss for PyTorch can be found [here](https://pytorch.org/docs/stable/generated/torch.nn.TripletMarginWithDistanceLoss.html#torch.nn.TripletMarginWithDistanceLoss). There are different variants of TripletLoss which can also boost performance and which you can implement by yourself, if you want:
# - use more that 1 sample of $p$ and $n$ for one embedding $e$
# - use special kinds of negatives: e.g. the negatives that are the most close to e (to boost them be further away from e)

# %% [markdown]
# **More to read about TripletLoss**:
#
# The idea of TripletLoss: https://en.wikipedia.org/wiki/Triplet_loss
#
# PyTorch implementation of TripletLoss: https://pytorch.org/docs/stable/generated/torch.nn.TripletMarginWithDistanceLoss.html#torch.nn.TripletMarginWithDistanceLoss

# %% [markdown]
# **Task**: implement a model and train it with TripletLoss. Play with margin parameter to achieve better results.
#
# Which loss among which you have tried is the best?
#
# **To get the full mark for this task you need to train a model using  TripletLoss correctly at least for one value of margin and achieve >=75% acc on test set.**
# As we don't have a classification layer in our network, we need a custom procedure for accuracy calculation. You can use one of the following procedures:
# - calculate accuracy on val and test sets using KNN with embeddings from training set as training points. (easy way)
# - compute mean embeddings for every class from training set and use them as reference embeddings. Then for every embedding v from val and test sets calculate cosine similarities between v and mean embeddings from train set. (the more "right" way, but requires code writing)
#
# You can use any of those two variants.
#
# **Hints**:
# - think of what the distance function $d$ should be in our case: training a model we want it to output embeddings which can be compared using cosine similarity function. Pay attention to that cosine similarity is not a distance measure — the more cosine distance, the closer embeddings are. Think how you can put cosine distance into TripletLoss function.
# - to train model using this loss you'll need to rewrite the Dataset class so it gives you not the random image and its label, but the image, positive images and negative images for this image;
# - don't forget to normalize embeddings for the loss! You may even do that by adding batchnorm/layernorm to the last layer of your network

# %%
import torch
import torch.nn as nn

def pairwise_distance_torch(embeddings, device):
    """Computes the pairwise distance matrix with numerical stability.
    output[i, j] = || feature[i, :] - feature[j, :] ||_2
    Args:
      embeddings: 2-D Tensor of size [number of data, feature dimension].
    Returns:
      pairwise_distances: 2-D Tensor of size [number of data, number of data].
    """

    # pairwise distance matrix with precise embeddings
    precise_embeddings = embeddings.to(dtype=torch.float32)

    c1 = torch.pow(precise_embeddings, 2).sum(axis=-1)
    c2 = torch.pow(precise_embeddings.transpose(0, 1), 2).sum(axis=0)
    c3 = precise_embeddings @ precise_embeddings.transpose(0, 1)

    c1 = c1.reshape((c1.shape[0], 1))
    c2 = c2.reshape((1, c2.shape[0]))
    c12 = c1 + c2
    pairwise_distances_squared = c12 - 2.0 * c3

    # Deal with numerical inaccuracies. Set small negatives to zero.
    pairwise_distances_squared = torch.max(pairwise_distances_squared, torch.tensor([0.]).to(device))
    # Get the mask where the zero distances are at.
    error_mask = pairwise_distances_squared.clone()
    error_mask[error_mask > 0.0] = 1.
    error_mask[error_mask <= 0.0] = 0.

    pairwise_distances = torch.mul(pairwise_distances_squared, error_mask)

    # Explicitly set diagonals to zero.
    mask_offdiagonals = torch.ones((pairwise_distances.shape[0], pairwise_distances.shape[1])) - torch.diag(torch.ones(pairwise_distances.shape[0]))
    pairwise_distances = torch.mul(pairwise_distances.to(device), mask_offdiagonals.to(device))
    return pairwise_distances

def TripletSemiHardLoss(y_true, y_pred, device ='cuda:0', margin=1.0):
    """Computes the triplet loss_functions with semi-hard negative mining.
       The loss_functions encourages the positive distances (between a pair of embeddings
       with the same labels) to be smaller than the minimum negative distance
       among which are at least greater than the positive distance plus the
       margin constant (called semi-hard negative) in the mini-batch.
       If no such negative exists, uses the largest negative distance instead.
       See: https://arxiv.org/abs/1503.03832.
       We expect labels `y_true` to be provided as 1-D integer `Tensor` with shape
       [batch_size] of multi-class integer labels. And embeddings `y_pred` must be
       2-D float `Tensor` of l2 normalized embedding vectors.
       Args:
         margin: Float, margin term in the loss_functions definition. Default value is 1.0.
         name: Optional name for the op.
       """

    labels, embeddings = y_true, y_pred

    # Reshape label tensor to [batch_size, 1].
    lshape = labels.shape
    labels = torch.reshape(labels, [lshape[0], 1])

    pdist_matrix = pairwise_distance_torch(embeddings, device)

    # Build pairwise binary adjacency matrix.
    adjacency = torch.eq(labels, labels.transpose(0, 1))
    # Invert so we can select negatives only.
    adjacency_not = adjacency.logical_not()

    batch_size = labels.shape[0]

    # Compute the mask.
    pdist_matrix_tile = pdist_matrix.repeat(batch_size, 1)
    adjacency_not_tile = adjacency_not.repeat(batch_size, 1)

    transpose_reshape = pdist_matrix.transpose(0, 1).reshape(-1, 1)
    greater = pdist_matrix_tile > transpose_reshape

    mask = adjacency_not_tile & greater

    # final mask
    mask_step = mask.to(dtype=torch.float32)
    mask_step = mask_step.sum(axis=1)
    mask_step = mask_step > 0.0
    mask_final = mask_step.reshape(batch_size, batch_size)
    mask_final = mask_final.transpose(0, 1)

    adjacency_not = adjacency_not.to(dtype=torch.float32)
    mask = mask.to(dtype=torch.float32)

    # negatives_outside: smallest D_an where D_an > D_ap.
    axis_maximums = torch.max(pdist_matrix_tile, dim=1, keepdim=True)
    masked_minimums = torch.min(torch.mul(pdist_matrix_tile - axis_maximums[0], mask), dim=1, keepdim=True)[0] + axis_maximums[0]
    negatives_outside = masked_minimums.reshape([batch_size, batch_size])
    negatives_outside = negatives_outside.transpose(0, 1)

    # negatives_inside: largest D_an.
    axis_minimums = torch.min(pdist_matrix, dim=1, keepdim=True)
    masked_maximums = torch.max(torch.mul(pdist_matrix - axis_minimums[0], adjacency_not), dim=1, keepdim=True)[0] + axis_minimums[0]
    negatives_inside = masked_maximums.repeat(1, batch_size)

    semi_hard_negatives = torch.where(mask_final, negatives_outside, negatives_inside)

    loss_mat = margin + pdist_matrix - semi_hard_negatives

    mask_positives = adjacency.to(dtype=torch.float32) - torch.diag(torch.ones(batch_size)).to(device)
    num_positives = mask_positives.sum()

    triplet_loss = (torch.max(torch.mul(loss_mat, mask_positives), torch.tensor([0.]).to(device))).sum() / num_positives
    triplet_loss = triplet_loss.to(dtype=embeddings.dtype)
    return triplet_loss

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

import torch.nn.functional as F
from sklearn.metrics import accuracy_score
import torch.optim as optim

optimizer =  optim.AdamW(model.parameters(), lr=1e-4)# favourite one
criterion = TripletSemiHardLoss

epochs = 15
clip = 1.5
alpha_c =1
train_history=[]
valid_history  = []
acc_history =[]
best_valid_loss = float('inf')
model.to(device)
for epoch in range(epochs):
  print(f"Start eposh #{epoch}")
  model.train()
  history = []
  i=0

  train_loss =0

  for train_batch in train_loader:

    images= torch.tensor(train_batch['image']).to(device)

    label = torch.tensor(train_batch['label']).to(device)
  
    output= model(images)
    model_emb = torch.nn.Sequential(*(list(model.children())[:-3]))
    emb =model_emb(images)
    emb = emb.squeeze(2).squeeze(2)
    optimizer.zero_grad()

    loss = criterion(label,emb)

    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
    optimizer.step()
    train_loss+=loss
      
    i+=1
  train_history.append(train_loss.detach().cpu().numpy()/i)
 
  model.eval()
  bath_size =0 
  val_loss=0
  
  acc = []

  for valid_batch in val_loader:
    images= torch.tensor(valid_batch['image']).to(device)
    label = torch.tensor(valid_batch['label']).to(device)

    output = model(images)
    model_emb = torch.nn.Sequential(*(list(model.children())[:-3]))
    emb =model_emb(images)
    emb = emb.squeeze(2).squeeze(2)
    loss = criterion(label,emb)
    val_loss+=loss
    bath_size+=1
    output  = torch.argmax(output, axis=1).cpu().detach().numpy()
    acc.append(accuracy_score(output,label.cpu().detach().numpy() ) )
  acc_history.append(np.array(acc).mean())
  valid_history.append(val_loss.detach().cpu().numpy()/bath_size)

  if True:
        plt.figure(figsize=(10, 10))
        clear_output(True)
        plt.plot(train_history, label='train loss')
        plt.plot(valid_history, label='val loss')
        plt.legend()    
        plt.show()

        plt.figure(figsize=(10, 10))
        plt.plot(acc_history, label='val acc')
        plt.legend()    
        plt.show()



  if val_loss < best_valid_loss:
        best_valid_loss = val_loss
        torch.save(model.state_dict(), '/content/gdrive/MyDrive/Colab Notebooks/project dls/best-val-model_tripl.pt')

  print(f"End eposh #{epoch}")
# Out:
# End eposh #0
# Start eposh #1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# ### ArcFace Loss (Additive Angular Margin Loss) (25% points)

# %% [markdown]
# This loss is somewhat "SOTA" for face recognition systems (somewhat — because actually different variants of losses and their combinations may be the best for different network architectures). This loss inherits idea from CE loss but further develops it to achieve better embeddings distribution on a sphere. It introduces some geodesic constraints to enhance intra-class compactness and inter-class discrepancy.

# %% [markdown]
# **How ArcFace loss works**:
#
# This loss is a variation of a standard SoftMax CE loss, which enforces embeddings of different classes (people) be further away: have a more sparse representation of embeddings in embedding space, enforce more evident gap between the nearest classes.

# %% [markdown]
# The standard SoftMax CE loss for classification task is presented as follows:
#
# $$L_{CE} = \frac{-1}{N}\sum_1^N \frac{e^{W_{y_i}^{T}x_i + b_{y_i}}}{\sum^n_{j=1}e^{W_j^Tx_i+b_j}},$$
#
# where:
# - $x_i \in \mathbb{R^d}$ denotes the deep feature of the $i$-th sample, belonging to the $y_i$-th class;
# - $W_j \in \mathbb{R^d}$ denotes the j-th column of the weight;
# - $W \in \mathbb{R^d}$ and $b_j \in \mathbb{R^d}$ is the bias term;
# - $N$ — batch size;
# - $n$ — class number.
#
# It appears, that, though this loss works well, it does not explicitly optimise the feature embedding to enforce higher similarity for intra- class samples and diversity for inter-class samples, which results in a performance gap for deep face recognition under large intra-class appearance variations.
#
# Let's do some work on this loss formula:
# - fix the bias $b_j=0$;
# - normalize weight ||$W_j$|| = 1;
# - normalize embedding ||$x_i$|| = 1 and re-scale it to s (s is a hyperparameter)
#
# The normalisation step on embeddings and weights makes the predictions only depend on the angle between the embedding and the weight. The learned embeddings fare thus distributed on a hypersphere with a radius of s.
#
# So we get the following loss function now:
#
# $$L = \frac{-1}{N}\sum_1^N \frac{e^{s\ cos\Theta_{y_i}}}{e^{s\ cos\Theta_{y_i}} + \sum^n_{j=1,\ j\ne y_i} e^{s\ cos\Theta_j}}$$
#
# Final step: let's add an additive angular margin penalty $m$ between $x_i$ and $W_{y_i}$ to simultaneously enhance the intra-class compactness and inter-class discrepancy:
#
# $$L_{ArcFace} = \frac{-1}{N}\sum_1^N \frac{e^{s\ cos(\Theta_{y_i} + m)}}{e^{s\ cos(\Theta_{y_i} + m)} + \sum^n_{j=1,\ j\ne y_i} e^{s\ cos\Theta_j}}$$
#
# SO this is an ArcFace loss. It has 2 hyperparameters: s and m.

# %% [markdown]
# The original paper to read about ArcFace more precisely: https://arxiv.org/pdf/1801.07698.pdf
#
# The original repo, where you can find a code sample: https://github.com/deepinsight/insightface

# %% [markdown]
# **Task**: implement a model and train it with ArcFace loss. Play with ArcFace loss parameters and see if you can beat a model with CE loss.
#
# To get the full mark for this task you need to train a model using TripletLoss correctly at least for one value of margin and achieve >=75% acc on test set.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Bonus task (5% points): Finding trash photos

# %% [markdown]
# You have probably noticed that in identification rate calculation we use cosine similarity between embeddings, which includes embeddings' normalization. And in TripletLoss also we normalize embeddings before passing them to the loss. Actually this is how most of the face recognition algorithms work — they are designed to output a normalized embeddings and any comparison between embeddings is done after the embeddings are normalized. Sometimes it may be beneficial even to add a normalization layer (batchnorm or layernorm with fixed parameters) after the model's embedding layer to make the model output normalized embeddings.
#
# But norms of the unnormalized embeddings can also be used. They can be used to detect trash photos — photos, where the face is presented really badly (e.g. back of the head instead of the forehead or even a photo without any head that has appeared in a dataset due to a mistake in face detection / landmarks detection algorithm).
#
# Empirically it has been found that the higher the embedding's norm, the more the probability of the corresponding photo to be trash is.

# %% [markdown]
# **Task**: get the embeddings of photos in a test set / query set / distractors set. Sort them by their norms. Output the photos whose embeddings norms are the highest. Do they look like normal or trash?
#
# **Doing this task will not give you points above 100% for the whole homework. But if you have any mistakes in previous sections, doing this task may give you additional points (5% of total points) to cover points lost.**

# %%
# YOUR CODE HERE

# %% [markdown]
# ## What's next

# %% [markdown]
# What else can you do with this homework:
# 1. Try to train the network on faces which are aligned differently (or not aligned at all). The dataset can be downloaded here[link text](https://drive.google.com/drive/folders/0B7EVK8r0v71pTUZsaXdaSnZBZzg?resourcekey=0-rJlzl934LzC-Xp28GeIBzQ)
# 2. Try to mix different losses while training. This often helps.
# 3. Try other losses from [this](https://arxiv.org/pdf/1901.05903.pdf) paper
# 4. Train bigger model on bigger dataset, as whole celebA, add [LFW](http://vis-www.cs.umass.edu/lfw/) and other
# 5. Explore embeddings spaces you get out of different models. How well are embeddings clasterized? Are they evenly spreaded on the sphere? How could you suggest to make it better?
